# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as smf

# %%
df=pd.read_csv("D:\Kartik DataScience\Python\Assignment 4\Salary_Data.csv")

# %%
df.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
df.corr()
# Out:
#                  YearsExperience    Salary
# YearsExperience         1.000000  0.978242
# Salary                  0.978242  1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     float64
# dtypes: float64(2)
# memory usage: 612.0 bytes

# %%
df.isna
# Out:
# <bound method DataFrame.isna of     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# ...

# %%
df.isna().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
df.shape
# Out:
# (30, 2)

# %%
df.describe()
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000

# %%
sns.scatterplot(x='YearsExperience', y='Salary', data=df)
plt.title('Scatter Plot of YearsExperience vs Salary')
plt.show()

# %%
from matplotlib import pyplot as plt
df['YearsExperience'].plot(kind='line', figsize=(8, 4), title='YearsExperience')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  from matplotlib import pyplot as plt
  import seaborn as sns
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['YearsExperience']
  ys = series['Salary']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = df.sort_values('YearsExperience', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('YearsExperience')
_ = plt.ylabel('Salary')

# %%
df.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
from sklearn.metrics import mean_absolute_error

model= smf.ols('Salary~YearsExperience',data=df).fit()
y_pred =model.predict(df['YearsExperience'])

print(mean_absolute_error(df['Salary'],y_pred))
y_pred
# Out:
# 4644.201289443538
# 0      36187.158752
# 1      38077.151217
# 2      39967.143681
# 3      44692.124842
# 4      46582.117306
# 5      53197.090931
# 6      54142.087163
# 7      56032.079627
# 8      56032.079627
# 9      60757.060788
# 10     62647.053252
# 11     63592.049484
# 12     63592.049484
# 13     64537.045717
# 14     68317.030645
# 15     72097.015574
# 16     73987.008038
# 17     75877.000502
# 18     81546.977895
# 19     82491.974127
# 20     90051.943985
# 21     92886.932681
# 22    100446.902538
# 23    103281.891235
# 24    108006.872395
# 25    110841.861092
# 26    115566.842252
# 27    116511.838485
# 28    123126.812110
# 29    125016.804574
# dtype: float64

# %%
df.describe()

# %%
# from sklearn.linear_model import LinearRegression
# from sklearn.ensemble import RandomForestRegressor
# lr = RandomForestRegressor(random_state=42,n_estimators=120,criterion='absolute_error', max_depth=15)
# lr.fit(df['YearsExperience'].values.reshape(-1,1),df['Salary'].values)
# y_pred =lr.predict(df['YearsExperience'].values.reshape(-1,1))

# print(mean_absolute_error(df['Salary'],y_pred))
# y_pred

# %%
test=pd.DataFrame({
        'YearsExperience':np.arange(1,10,0.2)})

# %%
test.head()
# Out:
#    YearsExperience
# 0              1.0
# 1              1.2
# 2              1.4
# 3              1.6
# 4              1.8

# %%
model.params
# Out:
# Intercept          25792.200199
# YearsExperience     9449.962321
# dtype: float64

# %%
model.predict(test)
# Out:
# 0      35242.162520
# 1      37132.154984
# 2      39022.147449
# 3      40912.139913
# 4      42802.132377
# 5      44692.124842
# 6      46582.117306
# 7      48472.109770
# 8      50362.102234
# 9      52252.094699
# 10     54142.087163
# 11     56032.079627
# 12     57922.072092
# 13     59812.064556
# 14     61702.057020
# 15     63592.049484
# 16     65482.041949
# 17     67372.034413
# 18     69262.026877
# 19     71152.019342
# 20     73042.011806
# 21     74932.004270
# 22     76821.996735
# 23     78711.989199
# 24     80601.981663
# 25     82491.974127
# 26     84381.966592
# 27     86271.959056
# 28     88161.951520
# 29     90051.943985
# 30     91941.936449
# 31     93831.928913
# 32     95721.921377
# 33     97611.913842
# 34     99501.906306
# 35    101391.898770
# 36    103281.891235
# 37    105171.883699
# 38    107061.876163
# 39    108951.868627
# 40    110841.861092
# 41    112731.853556
# 42    114621.846020
# 43    116511.838485
# 44    118401.830949
# ...

# %%
test['Salary_Predict'] = model.predict(test)

# %%
test
# Out:
#     YearsExperience  Salary_Predict
# 0               1.0    35242.162520
# 1               1.2    37132.154984
# 2               1.4    39022.147449
# 3               1.6    40912.139913
# 4               1.8    42802.132377
# 5               2.0    44692.124842
# 6               2.2    46582.117306
# 7               2.4    48472.109770
# 8               2.6    50362.102234
# 9               2.8    52252.094699
# 10              3.0    54142.087163
# 11              3.2    56032.079627
# 12              3.4    57922.072092
# 13              3.6    59812.064556
# 14              3.8    61702.057020
# 15              4.0    63592.049484
# 16              4.2    65482.041949
# 17              4.4    67372.034413
# 18              4.6    69262.026877
# 19              4.8    71152.019342
# 20              5.0    73042.011806
# 21              5.2    74932.004270
# 22              5.4    76821.996735
# 23              5.6    78711.989199
# 24              5.8    80601.981663
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  from matplotlib import pyplot as plt
  import seaborn as sns
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['YearsExperience']
  ys = series['Salary_Predict']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
test_sorted = test.sort_values('YearsExperience', ascending=True)
_plot_series(test_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('YearsExperience')
_ = plt.ylabel('Salary_Predict')

# %%
from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  from matplotlib import pyplot as plt
  import seaborn as sns
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['YearsExperience']
  ys = series['Salary']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = df.sort_values('YearsExperience', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('YearsExperience')
_ = plt.ylabel('Salary')
